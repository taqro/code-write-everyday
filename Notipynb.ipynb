# %% [markdown]
# <a href="https://colab.research.google.com/github/taqro/code-write-everyday/blob/master/Notipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = int(input())

if x == 0:
  print(1)
else:
  print(0)
# Out:
# 1
# 0
